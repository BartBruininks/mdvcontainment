# %%
import mdvcontainment as mdvc
import MDAnalysis as mda
import numpy as np
import matplotlib.pyplot as plt
import webbrowser

# %% [markdown]
# ## Data generation funtions

# %%
def make_test_universe(array_fill, array_empty, dim=(100,100,10), angles=(90,90,90)):
    """
    Returns a universe filled with the specified points.
    """
    
    # Creating the empty univerese
    universe = mda.Universe.empty(
        n_atoms = array_fill.shape[0] + array_empty.shape[0],
        trajectory = True,
    )
    
    # Fill the universe with the positions
    universe.atoms.positions = np.vstack([array_fill, array_empty])
    
    # Creating the atom names
    names = ['A']*array_fill.shape[0] + ['B']*array_empty.shape[0]
    universe.add_TopologyAttr('name', names)
    
    # Add the PBC conditions
    universe.dimensions = [*dim, *angles]
    return universe

# %%
# Creating a 2D island scenario
def make_island_2D(name='island_2D.gro', roll=0):
    """
    Returns and writes the atomgroup for a simple island in the ocean (2D).
    """

    # Creating the boolean mask.
    shape = (10, 10, 1)
    voxels = np.zeros(shape)
    voxels[3:7, 3:7, 0] = 1
    # Translate periodically 
    voxels = np.roll(voxels, roll, 0)
    voxels = np.roll(voxels, roll, 1)
    plt.imshow(voxels)
    
    # Converting coordinates from anghstrom to nm 
    #  and adding a 0.5 nm offset. 
    coordinates_fill = (np.vstack(np.where(voxels != 0)).T)*10 + 5
    coordinates_empty = (np.vstack(np.where(voxels == 0)).T)*10 + 5

    # Creating the universe
    test_universe = make_test_universe(coordinates_fill, coordinates_empty)
    test_universe.atoms.write(name)
    return test_universe

# %%
def make_nested_island_2D(name='nested_island_2D.gro', roll=0):
    """
    Returns and writes the atomgroup for a nesyed island in the ocean (2D).
    """

    # Creating the boolean mask
    shape = (10, 10, 1)
    voxels = np.zeros(shape)
    voxels[2:8, 2:8, 0] = 1
    voxels[3:7, 3:7, 0] = 0
    voxels[4:6, 4:6, 0] = 1
    # Translate periodically 
    voxels = np.roll(voxels, roll, 0)
    voxels = np.roll(voxels, roll, 1)
    plt.imshow(voxels)
    
    # Converting coordinates from anghstrom to nm 
    #  and adding a 0.5 nm offset. 
    coordinates_fill = (np.vstack(np.where(voxels != 0)).T)*10 + 5
    coordinates_empty = (np.vstack(np.where(voxels == 0)).T)*10 + 5

    # Creating the universe
    test_universe = make_test_universe(coordinates_fill, coordinates_empty)
    test_universe.atoms.write(name)
    return test_universe

# %% [markdown]
# ## Island (2D)

# %%
# Generate the test data
base_name = 'island_2D'
make_island_2D(base_name + '.gro')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# <Universe with 100 atoms>

# %%
# Load the GRO
u = mda.Universe(base_name + '.gro')
# Make the required selection
selection = u.select_atoms('name is A')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))

# %%
# Generate the containment hierarchy
containers = mdvc.Containers(selection.atoms, resolution=1, blur_amount=0)
# Out:
# Creating voxel masks with a resolution of 1...
# Blurring voxel masks with 0...
# Non PBC-labeling...
# Obtaining bridges...
# Calculating the ranks...
# The ranks are {(1,): 1, (-1,): 3}
# Calculating the pairs...
# Relabeling taking PBC into account...
# Creating graphs...
# Annotating the containment graph...
# Done!

# %%
# Plot the containment hierarchy as nodes (size is occupancy)
containers.plot(name=base_name + '.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# island_2D.html
#         <iframe
#             width="800px"
#             height="800px"
#             src="island_2D.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Render using VMD
containers.render(prefix=base_name + '_')
containers.load_renders(prefix=base_name + '_')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: names, resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# Container -1
# ------------------------
# {'UNK': 84}
# I wrote island_2D_-1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file island_2D_-1.gro
# Info) Using plugin gro for coordinates from file island_2D_-1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file island_2D_-1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 84
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 84
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 84   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 1.58 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  island_2D_-1.png
#
#
# Container 1
# ------------------------
# {'UNK': 16}
# I wrote island_2D_1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file island_2D_1.gro
# Info) Using plugin gro for coordinates from file island_2D_1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file island_2D_1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 16
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 16
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 16   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 1
# 1
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.37 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  island_2D_1.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# containment_img.html

# %%
# Plot using the VMD imagaes
containers.plot(name=base_name + '_renders.html')
# Open in a new tab, for the images in the graph are not shown in jupyter notebook
webbrowser.open_new_tab(base_name + '_renders.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# island_2D_renders.html
# True

# %% [markdown]
# ### Nested islands (2D)

# %%
# Generate the test data
base_name = 'nested_island_2D'
make_nested_island_2D(base_name + '.gro')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# <Universe with 100 atoms>

# %%
# Load the GRO
u = mda.Universe(base_name + '.gro')
selection = u.select_atoms('name is A')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))

# %%
# Generate the containment hierarchy
containers = mdvc.Containers(selection.atoms, resolution=1, blur_amount=0)
# Out:
# Creating voxel masks with a resolution of 1...
# Blurring voxel masks with 0...
# Non PBC-labeling...
# Obtaining bridges...
# Calculating the ranks...
# The ranks are {(1,): 1, (2,): 1, (-2,): 1, (-1,): 3}
# Calculating the pairs...
# Relabeling taking PBC into account...
# Creating graphs...
# Annotating the containment graph...
# Done!

# %%
# Plot the containment hierarchy as nodes (size is occupancy)
containers.plot(name= base_name + '.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# nested_island_2D.html
#         <iframe
#             width="800px"
#             height="800px"
#             src="nested_island_2D.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Render using VMD
containers.render(prefix=base_name + '_')
containers.load_renders(prefix=base_name + '_')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: names, resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# Container -2
# ------------------------
# {'UNK': 64}
# I wrote nested_island_2D_-2.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_-2.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_-2.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_-2.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 64
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 64
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 64   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 1.16 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_-2.png
#
#
# Container -1
# ------------------------
# {'UNK': 12}
# I wrote nested_island_2D_-1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_-1.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_-1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_-1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 12
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 12
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 12   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.46 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_-1.png
#
#
# Container 1
# ------------------------
# {'UNK': 20}
# I wrote nested_island_2D_1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_1.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 20
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 20
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 20   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 1
# 1
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.58 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_1.png
#
#
# Container 2
# ------------------------
# {'UNK': 4}
# I wrote nested_island_2D_2.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_2.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_2.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_2.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 4
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 4
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 4   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 2
# 2
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.29 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_2.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# containment_img.html

# %%
# Plot using the VMD imagaes
containers.plot(name= base_name + '_renders.html')
# Open in a new tab, for the images in the graph are not shown in jupyter notebook
webbrowser.open_new_tab(base_name + '_renders.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# nested_island_2D_renders.html
# True

# %% [markdown]
# ### Nested islands shifted (2D)

# %%
# Generate the test data
base_name = 'nested_island_2D_rolled'
make_nested_island_2D(base_name + '.gro', roll=5)
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# <Universe with 100 atoms>

# %%
# Load the GRO
u = mda.Universe(base_name + '.gro')
selection = u.select_atoms('name is A')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))

# %%
# Generate the containment hierarchy
containers = mdvc.Containers(selection.atoms, resolution=1, blur_amount=0)
# Out:
# Creating voxel masks with a resolution of 1...
# Blurring voxel masks with 0...
# Non PBC-labeling...
# Obtaining bridges...
# Calculating the ranks...
# The ranks are {(1, 4, 7, 8): 1, (2, 3, 5, 6): 1, (-5, -4, -3, -1): 1, (-2,): 3}
# Calculating the pairs...
# Relabeling taking PBC into account...
# Creating graphs...
# Annotating the containment graph...
# Done!

# %%
# Plot the containment hierarchy as nodes (size is occupancy)
containers.plot(name= base_name + '.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# nested_island_2D_rolled.html
#         <iframe
#             width="800px"
#             height="800px"
#             src="nested_island_2D_rolled.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Render using VMD
containers.render(prefix=base_name + '_')
containers.load_renders(prefix=base_name + '_')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: names, resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# Container -2
# ------------------------
# {'UNK': 64}
# I wrote nested_island_2D_rolled_-2.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_rolled_-2.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_rolled_-2.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_rolled_-2.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 64
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 64
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 64   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 1.25 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_rolled_-2.png
#
#
# Container -1
# ------------------------
# {'UNK': 12}
# I wrote nested_island_2D_rolled_-1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_rolled_-1.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_rolled_-1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_rolled_-1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 12
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 12
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 12   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.46 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_rolled_-1.png
#
#
# Container 1
# ------------------------
# {'UNK': 4}
# I wrote nested_island_2D_rolled_1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_rolled_1.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_rolled_1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_rolled_1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 4
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 4
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 4   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 1
# 1
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.29 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_rolled_1.png
#
#
# Container 2
# ------------------------
# {'UNK': 20}
# I wrote nested_island_2D_rolled_2.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_rolled_2.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_rolled_2.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_rolled_2.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 20
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 20
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 20   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 2
# 2
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.58 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_rolled_2.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# containment_img.html

# %%
# Plot using the VMD imagaes
containers.plot(name= base_name + '_renders.html')
# Open in a new tab, for the images in the graph are not shown in jupyter notebook
webbrowser.open_new_tab(base_name + '_renders.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# nested_island_2D_rolled_renders.html
# True

# %% [markdown]
# ### Removing small holes using boolean closure

# %%
# Generate the test data
base_name = 'nested_island_2D_rolled_closed'
make_nested_island_2D(base_name + '.gro', roll=5)
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# <Universe with 100 atoms>

# %%
# Load the GRO
u = mda.Universe(base_name + '.gro')
selection = u.select_atoms('name is A')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))

# %%
# Generate the containment hierarchy
containers = mdvc.Containers(selection.atoms, resolution=1, blur_amount=1)
# Out:
# Creating voxel masks with a resolution of 1...
# Blurring voxel masks with 1...
# Non PBC-labeling...
# Obtaining bridges...
# Calculating the ranks...
# The ranks are {(1, 2, 3, 4): 1, (-1,): 3}
# Calculating the pairs...
# Relabeling taking PBC into account...
# Creating graphs...
# Annotating the containment graph...
# Done!

# %%
# Plot the containment hierarchy as nodes (size is occupancy)
containers.plot(name= base_name + '.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# nested_island_2D_rolled_closed.html
#         <iframe
#             width="800px"
#             height="800px"
#             src="nested_island_2D_rolled_closed.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Render using VMD
containers.render(prefix=base_name + '_')
containers.load_renders(prefix=base_name + '_')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: names, resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# Container -1
# ------------------------
# {'UNK': 64}
# I wrote nested_island_2D_rolled_closed_-1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_rolled_closed_-1.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_rolled_closed_-1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_rolled_closed_-1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 64
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 64
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 64   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 1.26 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_rolled_closed_-1.png
#
#
# Container 1
# ------------------------
# {'UNK': 36}
# I wrote nested_island_2D_rolled_closed_1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 26GB (85%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_island_2D_rolled_closed_1.gro
# Info) Using plugin gro for coordinates from file nested_island_2D_rolled_closed_1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_island_2D_rolled_closed_1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 36
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 36
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 36   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 1
# 1
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.45 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_island_2D_rolled_closed_1.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# containment_img.html

# %%
# Plot using the VMD imagaes
containers.plot(name= base_name + '_renders.html')
# Open in a new tab, for the images in the graph are not shown in jupyter notebook
webbrowser.open_new_tab(base_name + '_renders.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# nested_island_2D_rolled_closed_renders.html
# True
