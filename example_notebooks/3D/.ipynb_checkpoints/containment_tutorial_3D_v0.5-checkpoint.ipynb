# %% [markdown]
# # Tutorial 2 - 3D Examples for MDVContainment
# To get acquanted with the functionalities of MDVContainment we start with 3D systems due to their clean visualization. Visualization of 3D systems makes use of VMD in this tutorial. However, feel free to visualize the generated GRO files with your favorite software.
#
# 1) Single island in ocean
# 2) Nested islands in ocean
# 3) Nested cylinders
# 4) Complex containment
#
# ## Dependencies

# %%
import mdvcontainment as mdvc
import MDAnalysis as mda
import numpy as np
import matplotlib.pyplot as plt
import webbrowser
import networkx as nx
import matplotlib.image as mpimg

# %% [markdown]
# ## Visualization wrapper

# %%
def visualize_3D(name, command_string='-e visualization.vmd'):
    """
    Visualizes the GRO file using the included render settings.

    Feel free to change this function to whatever visualizer you prefer.
    """
    # Plot using VMD
    # !vmd $name $command_string
    return

# %%
def draw_containment_nx(G, images, write=True, fname='containment.png', imsize=0.2, lwidth=1, nodesize=0, dpi=300):
    """
    Draws the containment graph using networkx and the provided images.

    Returns the plot object.
    """
    node_size = np.max(mpimg.imread(images[list(images.keys())[0]]).shape)*nodesize

    # The amount of images
    N = len(images)

    # Setting up the layout of the graph coordinates
    #pos=nx.spring_layout(G,k=k)
    pos = nx.nx_agraph.graphviz_layout(G, prog='dot')

    # draw with images on nodes
    nx.draw_networkx(G,pos,width=lwidth,edge_color="grey",alpha=1, node_size=node_size, node_color='white', arrows=False)
    ax=plt.gca()
    ax.axis('off')
    fig=plt.gcf()
    trans = ax.transData.transform
    trans2 = fig.transFigure.inverted().transform
    for n in G.nodes():
        (x,y) = pos[n]
        xx,yy = trans((x,y)) # figure coordinates
        xa,ya = trans2((xx,yy)) # axes coordinates
        a = plt.axes([xa-imsize/2.0,ya-imsize/2.0, imsize, imsize ])
        a.imshow(mpimg.imread(images[n]))
        a.set_aspect('equal')
        a.axis('off')
    if write:
        plt.savefig(fname, dpi=dpi, bbox_inches="tight")
    return plt

# %% [markdown]
# ## Data generation funtions
# Some helper functions to easily generate GRO files from voxel masks.

# %%
def make_test_universe(voxels, angles=(90,90,90)):
    """
    Returns a universe filled with the specified points.
    """

    # Obtaining the PBC shape in Anghstrom (A)
    dim = np.array(voxels.shape)*10
    
    # Converting the voxels to points and 
    #  changing the distance unit from nm to A and 
    #  adding a 5 A offset. 
    coordinates_fill = (np.vstack(np.where(voxels != 0)).T)*10 + 5
    coordinates_empty = (np.vstack(np.where(voxels == 0)).T)*10 + 5
    
    # Creating the empty univerese
    universe = mda.Universe.empty(
        n_atoms = coordinates_fill.shape[0] + coordinates_empty.shape[0],
        trajectory = True,
    )
    
    # Fill the universe with the positions
    universe.atoms.positions = np.vstack([coordinates_fill, coordinates_empty])
    
    # Creating the atom names
    names = ['A']*coordinates_fill.shape[0] + ['B']*coordinates_empty.shape[0]
    universe.add_TopologyAttr('name', names)
    
    # Add the PBC conditions
    universe.dimensions = [*dim, *angles]
    
    return universe

# %%
def make_island_3D(name='island_3D.gro', roll=0, visualize=True):
    """
    Returns and writes the atomgroup for a simple island in the ocean (3D).
    """

    # Creating the boolean mask.
    shape = (10, 10 , 10)
    voxels = np.zeros(shape)
    voxels[3:7, 3:7, 3:7] = 1
    
    # Translate periodically 
    voxels = np.roll(voxels, roll, 0)
    voxels = np.roll(voxels, roll, 1)
    voxels = np.roll(voxels, roll, 2)

    # Creating the universe
    test_universe = make_test_universe(voxels)
    test_universe.atoms.write(name)

    # Plot
    if visualize:
        visualize_3D(name)
    
    return test_universe

# %%
def make_nested_island_3D(name='nested_island_3D.gro', roll=0, visualize=True):
    """
    Returns and writes the atomgroup for a nesyed island in the ocean (3D).
    """

    # Creating the boolean mask
    shape = (10, 10 , 10)
    voxels = np.zeros(shape)
    voxels[2:8, 2:8, 2:8] = 1
    voxels[3:7, 3:7, 3:7] = 0
    voxels[4:6, 4:6, 4:6] = 1
    
    # Translate periodically 
    voxels = np.roll(voxels, roll, 0)
    voxels = np.roll(voxels, roll, 1)
    voxels = np.roll(voxels, roll, 2)

    # Creating the universe
    test_universe = make_test_universe(voxels)
    test_universe.atoms.write(name)

    # Plot
    if visualize:
        visualize_3D(name)
    
    return test_universe

# %%
def make_cylinders_3D(name='cylinder_3D.gro', roll=0, visualize=True):
    """
    Returns and writes the atomgroup for a system with nested rank1 cylinders (3D).
    """

    # Creating the boolean mask.
    shape = (10, 10 , 10)
    voxels = np.zeros(shape)
    
    # First row
    voxels[3:7, 3:7, :] = 1
    voxels[4:6, 4:6, :] = 0
    
    # Translate periodically 
    voxels = np.roll(voxels, roll, 0)
    voxels = np.roll(voxels, roll, 1)
    voxels = np.roll(voxels, roll, 1)

    # Creating the universe
    test_universe = make_test_universe(voxels)
    test_universe.atoms.write(name)

    # Plot
    if visualize:
        visualize_3D(name)
    
    return test_universe

# %%
def make_complex_3D(name='cylinder_3D.gro', roll=0, visualize=True):
    """
    Returns and writes the atomgroup for a complex system(3D).
    """

    # Creating the boolean mask.
    shape = (23, 10 , 10)
    voxels = np.zeros(shape)
    
    # Add the cylinders
    voxels[3:7, 3:7, :] = 1
    voxels[4:6, 4:6, :] = 0

    # Add the nested islands
    voxels[15:21, 2:8, 2:8] = 1
    voxels[16:20, 3:7, 3:7] = 0
    voxels[17:19, 4:6, 4:6] = 1

    # Add dividing plane
    voxels[10:13, :, :] = 1

    # Add island in dividing plane
    voxels[11, 5, 5] = 0
    
    # Translate periodically 
    voxels = np.roll(voxels, roll, 0)
    voxels = np.roll(voxels, roll, 1)
    voxels = np.roll(voxels, roll, 1)

    # Creating the universe
    test_universe = make_test_universe(voxels)
    test_universe.atoms.write(name)

    # Plot
    if visualize:
        visualize_3D(name)
    
    return test_universe

# %% [markdown]
# ## 1 - Island
# This is the most basic of containment hierarchies. We do not use blurring, as we have voxel perfect input.

# %%
# Generate the test data
base_name = 'island_3D'
make_island_3D(base_name + '.gro', visualize=False) # Set visualize to true for a VMD rendering
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# <Universe with 1000 atoms>

# %%
# Load the GRO
u = mda.Universe(base_name + '.gro')
# Make the required selection
selection = u.select_atoms('name is A')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))

# %%
# Generate the containment hierarchy
containers = mdvc.Containers(selection.atoms, resolution=1, blur_amount=0)
# Out:
# Creating voxel masks with a resolution of 1...
# Blurring voxel masks with 0...
# Non PBC-labeling...
# Obtaining bridges...
# Calculating the ranks...
# The ranks are {(1,): 0, (-1,): 3}
# Calculating the pairs...
# Relabeling taking PBC into account...
# Creating graphs...
# Annotating the containment graph...
# Done!

# %%
# Write the components pdb (the components are in the beta field, the containment in the containment.vmd)
containers.write_components(fname_struc=f'{base_name}_containment.pdb', fname_vmd=f'{base_name}_containment.vmd')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'altLocs' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'icodes' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'chainIDs' Using default value of ''
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'occupancies' Using default value of '1.0'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'record_types' Using default value of 'ATOM'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1176: UserWarning: Found missing chainIDs. Corresponding atoms will use value of 'X'
#   warnings.warn("Found missing chainIDs."

# %%
## Show the objects (use as selection all, with visualization of VDW and coloring set to beta to see the components)
# visualize_3D(f'{base_name}_containment.pdb', command_string='-e components.vmd')

# %%
# Draw the raw containment graph using networkx
nx.draw_networkx(containers.containment_graph)

# %%
#comment
# This has to be the first line to capture the output
# Render using VMD and (custom) render scripts
containers.render(prefix=base_name + '_')
containers.load_renders(prefix=base_name + '_')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: names, resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# Container -1
# ------------------------
# {'UNK': 936}
# I wrote island_3D_-1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 29GB (92%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file island_3D_-1.gro
# Info) Using plugin gro for coordinates from file island_3D_-1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file island_3D_-1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 936
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 936
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 936   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 13.94 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  island_3D_-1.png
#
#
# Container 1
# ------------------------
# {'UNK': 64}
# I wrote island_3D_1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 29GB (92%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file island_3D_1.gro
# Info) Using plugin gro for coordinates from file island_3D_1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file island_3D_1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 64
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 64
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 64   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 1
# 1
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.47 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  island_3D_1.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# containment_img.html

# %%
# Plot using nx matplotlib and the VMD images
draw_containment_nx(containers.containment_graph, containers._images, imsize=0.4, write=True, fname=f'{base_name}_containment.png', dpi=600)
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/pygraphviz/agraph.py:1407: RuntimeWarning: Warning: 1.0 is not a known color.
# Warning: 0.06837606837606838 is not a known color.
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
# <module 'matplotlib.pyplot' from '/home/bart/.virtualenvs/containment/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## 2 - Nested Islands
# A slightly more elaborate containment hierarchy, we still turn off blurring as we have voxel perfect input.

# %%
# Generate the test data
base_name = 'nested_islands_3D'
make_nested_island_3D(base_name + '.gro', visualize=False)
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# <Universe with 1000 atoms>

# %%
# Load the GRO
u = mda.Universe(base_name + '.gro')
selection = u.select_atoms('name is A')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))

# %%
# Generate the containment hierarchy
containers = mdvc.Containers(selection.atoms, resolution=1, blur_amount=0)
# Out:
# Creating voxel masks with a resolution of 1...
# Blurring voxel masks with 0...
# Non PBC-labeling...
# Obtaining bridges...
# Calculating the ranks...
# The ranks are {(1,): 0, (2,): 0, (-2,): 0, (-1,): 3}
# Calculating the pairs...
# Relabeling taking PBC into account...
# Creating graphs...
# Annotating the containment graph...
# Done!

# %%
# Write the components pdb (the components are in the beta field, the containment in the containment.vmd)
containers.write_components(fname_struc=f'{base_name}_containment.pdb', fname_vmd=f'{base_name}_containment.vmd')
; # suppresses the MDA printing
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'altLocs' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'icodes' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'chainIDs' Using default value of ''
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'occupancies' Using default value of '1.0'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'record_types' Using default value of 'ATOM'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1176: UserWarning: Found missing chainIDs. Corresponding atoms will use value of 'X'
#   warnings.warn("Found missing chainIDs."
# '# suppresses the MDA printing'

# %%
## Show the objects (use as selection all, with visualization of VDW and coloring set to beta to see the components)
#visualize_3D(f'components_{base_name}.pdb', command_string='-e components.vmd')

# %%
# Draw the raw containment graph using networkx
nx.draw_networkx(containers.containment_graph)

# %%
# Render using VMD
containers.render(prefix=base_name + '_')
containers.load_renders(prefix=base_name + '_')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: names, resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# Container -2
# ------------------------
# {'UNK': 784}
# I wrote nested_islands_3D_-2.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (92%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_islands_3D_-2.gro
# Info) Using plugin gro for coordinates from file nested_islands_3D_-2.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_islands_3D_-2.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 784
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 784
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 784   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 19.30 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_islands_3D_-2.png
#
#
# Container -1
# ------------------------
# {'UNK': 56}
# I wrote nested_islands_3D_-1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_islands_3D_-1.gro
# Info) Using plugin gro for coordinates from file nested_islands_3D_-1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_islands_3D_-1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 56
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 56
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 56   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 2.76 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_islands_3D_-1.png
#
#
# Container 1
# ------------------------
# {'UNK': 152}
# I wrote nested_islands_3D_1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_islands_3D_1.gro
# Info) Using plugin gro for coordinates from file nested_islands_3D_1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_islands_3D_1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 152
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 152
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 152   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 1
# 1
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 7.72 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_islands_3D_1.png
#
#
# Container 2
# ------------------------
# {'UNK': 8}
# I wrote nested_islands_3D_2.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_islands_3D_2.gro
# Info) Using plugin gro for coordinates from file nested_islands_3D_2.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_islands_3D_2.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 2
# 2
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.32 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_islands_3D_2.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# containment_img.html

# %%
# Plot using nx matplotlib and the VMD images
draw_containment_nx(containers.containment_graph, containers._images, imsize=0.12, write=True, fname=f'{base_name}_containment.png', dpi=600)
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/pygraphviz/agraph.py:1407: RuntimeWarning: Warning: 1.0 is not a known color.
# Warning: 0.19387755102040816 is not a known color.
# Warning: 0.07142857142857142 is not a known color.
# Warning: 0.01020408163265306 is not a known color.
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
# <module 'matplotlib.pyplot' from '/home/bart/.virtualenvs/containment/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # 3 - Nested Cylinders

# %%
# Generate the test data
base_name = 'nested_cylinders_3D'
make_cylinders_3D(base_name + '.gro', visualize=False)
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# <Universe with 1000 atoms>

# %%
# Load the GRO
u = mda.Universe(base_name + '.gro')
selection = u.select_atoms('name is A')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))

# %%
# Generate the containment hierarchy
containers = mdvc.Containers(selection.atoms, resolution=1, blur_amount=0)
# Out:
# Creating voxel masks with a resolution of 1...
# Blurring voxel masks with 0...
# Non PBC-labeling...
# Obtaining bridges...
# Calculating the ranks...
# The ranks are {(1,): 1, (-2,): 1, (-1,): 3}
# Calculating the pairs...
# Relabeling taking PBC into account...
# Creating graphs...
# Annotating the containment graph...
# Done!

# %%
# Write the components pdb (the components are in the beta field, the containment in the containment.vmd)
containers.write_components(fname_struc=f'{base_name}_containment.pdb', fname_vmd=f'{base_name}_containment.vmd')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'altLocs' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'icodes' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'chainIDs' Using default value of ''
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'occupancies' Using default value of '1.0'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'record_types' Using default value of 'ATOM'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1176: UserWarning: Found missing chainIDs. Corresponding atoms will use value of 'X'
#   warnings.warn("Found missing chainIDs."

# %%
## Show the objects (use as selection all, with visualization of VDW and coloring set to beta to see the components)
#visualize_3D(f'{base_name}_containment.pdb', command_string='-e components.vmd')

# %%
# Draw the raw containment graph using networkx
nx.draw_networkx(containers.containment_graph)

# %%
# Render using VMD
containers.render(prefix=base_name + '_')
containers.load_renders(prefix=base_name + '_')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: names, resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# Container -2
# ------------------------
# {'UNK': 840}
# I wrote nested_cylinders_3D_-2.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_cylinders_3D_-2.gro
# Info) Using plugin gro for coordinates from file nested_cylinders_3D_-2.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_cylinders_3D_-2.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 840
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 840
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 840   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 14.50 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_cylinders_3D_-2.png
#
#
# Container -1
# ------------------------
# {'UNK': 40}
# I wrote nested_cylinders_3D_-1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (92%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_cylinders_3D_-1.gro
# Info) Using plugin gro for coordinates from file nested_cylinders_3D_-1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_cylinders_3D_-1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 40
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 40
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 40   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.35 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_cylinders_3D_-1.png
#
#
# Container 1
# ------------------------
# {'UNK': 120}
# I wrote nested_cylinders_3D_1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file nested_cylinders_3D_1.gro
# Info) Using plugin gro for coordinates from file nested_cylinders_3D_1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file nested_cylinders_3D_1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 120
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 120
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 120   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 1
# 1
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 5.92 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  nested_cylinders_3D_1.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# containment_img.html

# %%
# Plot using nx matplotlib and the VMD images
draw_containment_nx(containers.containment_graph, containers._images, imsize=0.2, write=True, fname=f'{base_name}_containment.png', dpi=600)
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/pygraphviz/agraph.py:1407: RuntimeWarning: Warning: 1.0 is not a known color.
# Warning: 0.14285714285714285 is not a known color.
# Warning: 0.047619047619047616 is not a known color.
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
# <module 'matplotlib.pyplot' from '/home/bart/.virtualenvs/containment/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # 4 -  Complex containment

# %%
# Generate the test data
base_name = 'complex_3D'
make_complex_3D(base_name + '.gro', visualize=False)
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# <Universe with 2300 atoms>

# %%
# Load the GRO
u = mda.Universe(base_name + '.gro')
selection = u.select_atoms('name is A')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))

# %%
# Generate the containment hierarchy
containers = mdvc.Containers(selection.atoms, resolution=1, blur_amount=0)
# Out:
# Creating voxel masks with a resolution of 1...
# Blurring voxel masks with 0...
# Non PBC-labeling...
# Obtaining bridges...
# Calculating the ranks...
# The ranks are {(1,): 1, (2,): 2, (3,): 0, (4,): 0, (-5,): 0, (-4, -1): 2, (-3,): 0, (-2,): 1}
# Calculating the pairs...
# Relabeling taking PBC into account...
# Creating graphs...
# Annotating the containment graph...
# Done!

# %%
# Write the components pdb (the components are in the beta field, the containment in the containment.vmd)
containers.write_components(fname_struc=f'{base_name}_containment.pdb', fname_vmd=f'{base_name}_containment.vmd')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'altLocs' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'icodes' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'chainIDs' Using default value of ''
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'occupancies' Using default value of '1.0'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'record_types' Using default value of 'ATOM'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1129: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1176: UserWarning: Found missing chainIDs. Corresponding atoms will use value of 'X'
#   warnings.warn("Found missing chainIDs."

# %%
## Show the objects (use as selection all, with visualization of VDW and coloring set to beta to see the components)
#visualize_3D(f'{base_name}_containment.pdb', command_string='-e components.vmd')

# %%
# Draw the raw containment graph using networkx
nx.draw_networkx(containers.containment_graph, )

# %%
# Render using VMD
containers.render(prefix=base_name + '_')
containers.load_renders(prefix=base_name + '_')
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: names, resnames, resids. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# Container -4
# ------------------------
# {'UNK': 40}
# I wrote complex_3D_-4.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file complex_3D_-4.gro
# Info) Using plugin gro for coordinates from file complex_3D_-4.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file complex_3D_-4.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 40
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 40
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 40   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.28 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  complex_3D_-4.png
#
#
# Container -3
# ------------------------
# {'UNK': 1}
# I wrote complex_3D_-3.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file complex_3D_-3.gro
# Info) Using plugin gro for coordinates from file complex_3D_-3.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file complex_3D_-3.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 1
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 1
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 1   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.26 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  complex_3D_-3.png
#
#
# Container -2
# ------------------------
# {'UNK': 56}
# I wrote complex_3D_-2.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file complex_3D_-2.gro
# Info) Using plugin gro for coordinates from file complex_3D_-2.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file complex_3D_-2.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 56
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 56
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 56   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 1.28 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  complex_3D_-2.png
#
#
# Container -1
# ------------------------
# {'UNK': 1624}
# I wrote complex_3D_-1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file complex_3D_-1.gro
# Info) Using plugin gro for coordinates from file complex_3D_-1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file complex_3D_-1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 1624
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 1624
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 1624   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# -
# -
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 10.33 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  complex_3D_-1.png
#
#
# Container 1
# ------------------------
# {'UNK': 120}
# I wrote complex_3D_1.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (92%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file complex_3D_1.gro
# Info) Using plugin gro for coordinates from file complex_3D_1.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file complex_3D_1.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 120
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 120
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 120   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 1
# 1
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 2.93 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  complex_3D_1.png
#
#
# Container 2
# ------------------------
# {'UNK': 299}
# I wrote complex_3D_2.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file complex_3D_2.gro
# Info) Using plugin gro for coordinates from file complex_3D_2.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file complex_3D_2.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 299
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 299
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 299   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 2
# 2
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 2.43 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  complex_3D_2.png
#
#
# Container 3
# ------------------------
# {'UNK': 152}
# I wrote complex_3D_3.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 29GB (92%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file complex_3D_3.gro
# Info) Using plugin gro for coordinates from file complex_3D_3.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file complex_3D_3.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 152
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 152
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 152   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 3
# 3
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 2.81 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  complex_3D_3.png
#
#
# Container 4
# ------------------------
# {'UNK': 8}
# I wrote complex_3D_4.gro
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) http://www.ks.uiuc.edu/Research/vmd/
# Info) Email questions and bug reports to vmd@ks.uiuc.edu
# Info) Please include this reference in published work using VMD:
# Info)    Humphrey, W., Dalke, A. and Schulten, K., `VMD - Visual
# Info)    Molecular Dynamics', J. Molec. Graphics 1996, 14.1, 33-38.
# Info) -------------------------------------------------------------
# Info) Multithreading available, 16 CPUs.
# Info)   CPU features: SSE2 SSE4.1 AVX AVX2 FMA F16 HT
# Info) Free system memory: 28GB (91%)
# Info) Creating CUDA device pool and initializing hardware...
# Info) Detected 1 available CUDA accelerator::
# Info) [0] Quadro T2000 with Max-Q Design 16 SM_7.5 1.4 GHz, 3.8GB RAM SP32 KT AE3 ZC
# Info) OpenGL renderer: Mesa Intel(R) UHD Graphics (CML GT2)
# Info)   Features: STENCIL MSAA(4) MDE CVA MTX NPOT PP PS GLSL(OVFS)
# Info)   Full GLSL rendering mode is available.
# Info)   Textures: 2-D (16384x16384), 3-D (512x512x512), Multitexture (8)
# OpenGLDisplayDevice) Creating OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context created.
# Info) Detected 1 available TachyonL/OptiX ray tracing accelerator
# Info)   Compiling  OptiX shaders on 1 target GPU...
# Info) File loading in progress, please wait.
# Info) Using plugin gro for structure file complex_3D_4.gro
# Info) Using plugin gro for coordinates from file complex_3D_4.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file complex_3D_4.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
# Info) Using plugin gro for structure file box_corners.gro
# Info) Using plugin gro for coordinates from file box_corners.gro
# Info) Determining bond structure from distance search ...
# Info) Finished with coordinate file box_corners.gro.
# Info) Analyzing structure ...
# Info)    Atoms: 8
# Info)    Bonds: 0
# Info)    Angles: 0  Dihedrals: 0  Impropers: 0  Cross-terms: 0
# Info)    Bondtypes: 0  Angletypes: 0  Dihedraltypes: 0  Impropertypes: 0
# Info)    Residues: 8
# Info)    Waters: 0
# Info)    Segments: 1
# Info)    Fragments: 8   Protein: 0   Nucleic: 0
#
#  USAGE
# -------
#
# These few lines are given by the "cg_bonds_usage" command.
#
# Draw bonds for specific molecules.
#    cg_bonds [OPTIONS]
#
# If you ask to this script to draw Martini/elastic network from a .tpr file, it will use the "gmx" executable compiled with gromacs. By default, it looks for it in the "/usr/bin" directory; you can specify another path pointing to the executable (see below). If you ask to read a .top file, it will read the paths to the .itp files from the "#include" statements; make sure those paths are valid...
#
# Options and default values:
#    -molid     "top"                VMD-defined ID of the molecule to process
#    -gmx       /usr/bin/gmx         path to the "gmx" executable
#    -tpr       topol.tpr            path to the simulation file (.tpr)
#    -top       topol.top            path to the system topology files (.top linking to .itp)
#    -topoltype "martini"            type of topology(martini|elastic|elnedyn)
#    -net       "martini"            network to draw (martini|elastic|both)
#    -bndrcnstr "both"               draw bonds AND/OR constraints (bonds|constraints|both)
#    -cutoff    7.0                  cutoff for bonds/constraints [angstroms]
#    -color     "red"                color (color name or VMD-defined ID) of elastic bonds
#    -mat       "Opaque"             material for elastic bonds
#    -rad       0.2                  radius of elastic bonds
#    -res       6                    resolution of elastic bonds
#
# In most of the cases, if a "classical" cutoff is used for the elastic network (0.9nm), more than 12 elastic "bonds" per bead are defined and VMD refuses to draw them. BUT this script replaces bonds by cylinders, and is able to draw the entire elastic network. Note that you will have to modify the default cutoff value to see all the "bonds" defined by the elastic network. These drawings are not dynamic, you will need to re-draw the entire network each step of a trajectory.
#
# Delete the Martini network:
#    cg_delete_martini_bonds [OPTION]
#
# Delete the elastic network:
#    cg_delete_elastic_bonds [OPTION]
#
# Shortcut (delete everything, including bonds/constraints lists):
#    cg_delete_all [OPTION]
#
# The only option for the previous three commands is the VMD-defined ID of the molecule to process (via -molid, default is "top").
#
# Someone (...) said the names of the functions were too long; you can find some shortcuts here:
#    cg_bonds_usage            cg_bus
#    cg_delete_martini_bonds   cg_dmb
#    cg_delete_elastic_bonds   cg_deb
#    cg_delete_all             cg_dab
#
#  EXAMPLES
# ----------
#
#    cg_bonds -tpr mini.tpr
#    cg_bonds -gmx gmx -tpr mini.tpr
#    cg_bonds -gmx /usr/local/gromacs-2016.3/bin/gmx -topoltype "martini" -top system.top -cutoff 6.2
#    cg_bonds -topoltype "elastic" -res 10 -cutoff 12.0 -mat Transparent -color 12
#    cg_dmb -molid 1
#
# The qwikfold package could not be loaded:
#
# 4
# 4
# 50
# 20
# Info) Rendering current scene to 'text_render.png' ...
# Info) Ambient occlusion enabled.
# Info) Shadow rendering enabled.
# OptiXDisplayDevice) Total rendering time: 0.27 sec
# Info) Rendering complete.
# Info) VMD for LINUXAMD64, version 1.9.4a55 (November 26, 2021)
# Info) Exiting normally.
# OpenGLDisplayDevice) Destroying OptiX RTRT context...
# OpenGLDisplayDevice) OptiX RTRT context destroyed.
#
#
# RENDER NAME
#
#  complex_3D_4.png
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# containment_img.html

# %%
# Plot using nx matplotlib and the VMD images
draw_containment_nx(containers.containment_graph, containers._images, imsize=0.2, write=True, fname=f'{base_name}_containment.png', dpi=600)
# Out:
# /home/bart/.virtualenvs/containment/lib/python3.8/site-packages/pygraphviz/agraph.py:1407: RuntimeWarning: Warning: 0.024630541871921183 is not a known color.
# Warning: 0.0006157635467980296 is not a known color.
# Warning: 0.034482758620689655 is not a known color.
# Warning: 0.0049261083743842365 is not a known color.
# Warning: 1.0 is not a known color.
# Warning: 0.07389162561576355 is not a known color.
# Warning: 0.09359605911330049 is not a known color.
# Warning: 0.18411330049261085 is not a known color.
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
# <module 'matplotlib.pyplot' from '/home/bart/.virtualenvs/containment/lib/python3.8/site-packages/matplotlib/pyplot.py'>
