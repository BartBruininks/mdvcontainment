# %%
import containment as mdvc
import MDAnalysis as mda
import networkx as nx
import numpy as np

# %%
path = '../../example_notebooks/2D/nested_island_2D_rolled.gro'
u = mda.Universe(path)
selection = u.select_atoms('name A')
# Out:
# /home/bart/.virtualenvs/mda/lib/python3.10/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: A
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))

# %%
containers = mdvc.Containers(selection, resolution=1, blur_amount=0)
# Out:
# Creating voxel masks with a resolution of 1...
# Blurring voxel masks 0 times...
# Non PBC-labeling...
# Calculating the contacts...
# Obtaining bridges...
# edges {(-5, -3), (-3, 6), (2, 2), (-4, 1), (-2, -2), (-1, -1), (7, 1), (-1, 7), (3, 6), (-3, 8), (6, -5), (1, 8), (4, -5), (5, -4), (8, -5), (5, 5), (8, 4), (-5, 4), (-3, 1), (2, -3), (6, -3), (-4, -4), (7, -4), (6, 6), (-4, 5), (-1, 2), (-2, 2), (5, -2), (5, -1), (8, -3), (-5, 6), (-3, 3), (-4, -1), (7, -1), (-4, 7), (-1, 4), (7, 7), (3, 3), (-5, 8), (1, -4), (-1, -3), (5, 2), (4, 4), (-3, -1), (1, -1), (1, 7), (-4, 2), (7, 8), (3, -2), (3, -1), (4, -3), (5, -5), (-5, 3), (-4, -5), (7, -5), (7, 4), (-5, -4), (5, 6), (4, 8), (-5, 5), (-3, 2), (8, 8), (-2, 5), (-2, 6), (3, 2), (4, 1), (-3, -5), (-5, 7), (-3, 4), (8, 1), (1, 4), (2, 3), (6, 3), (3, -5), (-3, -3), (1, -3), (2, -4), (2, 5), (6, -4), (6, 5), (-1, 1), (3, -3), (8, -4), (2, -2), (2, -1), (6, -2), (-4, 6), (-2, 3), (-1, 3), (4, -1), (-5, -5), (4, 7), (8, 7), (1, 1), (-1, -4), (-4, 8), (-1, 5)}
# pairs {(-5, -3), (-5, 3), (-5, 6), (-3, 3), (-3, 6), (2, 5), (-4, -1), (-4, 1), (-4, 7), (-1, 4), (-1, 1), (-1, 7), (-5, -4), (5, 6), (4, 8), (-5, 5), (-3, 2), (3, 6), (-5, 8), (-3, 8), (-1, 5), (1, 8), (-4, 6), (-2, 3), (-1, 3), (-2, 6), (-1, 2), (4, 7), (-5, 7), (-3, -1), (-3, 4), (-5, 4), (-3, 1), (1, 4), (2, 3), (1, 7), (-4, 2), (7, 8), (-4, 5), (-2, 2), (-4, 8), (-2, 5)}
# (-5, -3) was already in the list.
# (-5, 3) was already in the list.
# (-5, 6) was already in the list.
# (-3, 3) was already in the list.
# (-3, 6) was already in the list.
# (2, 5) was already in the list.
# (-4, -1) was already in the list.
# (-4, 1) was already in the list.
# (-4, 7) was already in the list.
# (-1, 4) was already in the list.
# (-1, 1) was already in the list.
# (-1, 7) was already in the list.
# (-5, -4) was already in the list.
# (5, 6) was already in the list.
# (4, 8) was already in the list.
# (-5, 5) was already in the list.
# (-3, 2) was already in the list.
# (3, 6) was already in the list.
# (-5, 8) was already in the list.
# (-3, 8) was already in the list.
# (-1, 5) was already in the list.
# (1, 8) was already in the list.
# (-4, 6) was already in the list.
# (-2, 3) was already in the list.
# (-1, 3) was already in the list.
# (-2, 6) was already in the list.
# (-1, 2) was already in the list.
# (4, 7) was already in the list.
# (-5, 7) was already in the list.
# (-3, -1) was already in the list.
# (-3, 4) was already in the list.
# (-5, 4) was already in the list.
# (-3, 1) was already in the list.
# (1, 4) was already in the list.
# (2, 3) was already in the list.
# (1, 7) was already in the list.
# (-4, 2) was already in the list.
# (7, 8) was already in the list.
# (-4, 5) was already in the list.
# (-2, 2) was already in the list.
# (-4, 8) was already in the list.
# (-2, 5) was already in the list.
# Calculating the ranks...
# The ranks are {(1, 4, 7, 8): 1, (2, 3, 5, 6): 1, (-5, -4, -3, -1): 1, (-2,): 3}
# Relabeling taking PBC into account...
# Creating graphs...
# Annotating the containment graph...
# Done!

# %%
containers.plot()
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# containment.html
#         <iframe
#             width="800px"
#             height="800px"
#             src="containment.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
nx.draw_networkx(containers.data['bridges'].graph)

# %%
nx.draw_networkx(containers.data['inv_bridges'].graph)

# %%
all_bridges = containers.data['all_bridges'].graph

# %%
nx.draw_networkx(all_bridges)

# %%
all_nodes = set(all_bridges.nodes())
nx.draw_networkx(all_bridges.subgraph(all_nodes - set([3,6,2,5])))
